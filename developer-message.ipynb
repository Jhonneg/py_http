# %%
from dotenv import load_dotenv, find_dotenv
from IPython.display import display_markdown
from openai import OpenAI

load_dotenv(find_dotenv(), override=True)


client = OpenAI()

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "user", "content": "Explain Object-Oriented Programming with Python"}
    ],
    stream=True,
)
### using markdown

# display_markdown(response.choices[0].delta.content, raw=True)

### using streaming

for chunk in response:
    if chunk.choices[0].delta.content is not None:
        print(chunk.choices[0].delta.content, end="")
# Out:
# Object-Oriented Programming (OOP) is a programming paradigm that uses objects and classes to structure code. It is based on several key concepts, including encapsulation, inheritance, polymorphism, and abstraction. Python, being an object-oriented language, supports OOP principles and allows developers to write clean, organized, and reusable code.
#
# ### Key Concepts of OOP
#
# 1. **Classes and Objects**:
#    - **Class**: A blueprint for creating objects. It defines a set of attributes and methods that the created objects will have.
#    - **Object**: An instance of a class. It encapsulates data and functions operating on that data.
#
#    ```python
#    class Dog:
#        def __init__(self, name, breed):
#            self.name = name
#            self.breed = breed
#
#        def bark(self):
#            return f"{self.name} says woof!"
#
#    my_dog = Dog("Buddy", "Golden Retriever")
#    print(my_dog.bark())
#    ```
#
# 2. **Encapsulation**:
#    - The bundling of data (attributes) and methods (functions) that operate on the data into a single unit or class. This also restricts access to some of the object's components, which can prevent accidental modification.
#    - In Python, attributes can be made private by prefixing their names with double underscores (`__`).
#
#    ```python
#    class BankAccount:
#        def __init__(self, balance=0):
#            self.__balance = balance  # private attribute
#
#        def deposit(self, amount):
#            self.__balance += amount
#
#        def get_balance(self):
#            return self.__balance
#
#    account = BankAccount()
#    account.deposit(100)
#    print(account.get_balance())  # Output: 100
#    ```
#
# 3. **Inheritance**:
#    - A mechanism by which one class can inherit attributes and methods from another class. This promotes code reusability.
#    - The base class (or parent class) is the class being inherited from, while the derived class (or child class) is the class that inherits.
#
#    ```python
#    class Animal:
#        def speak(self):
#            return "Animal speaks"
#
#    class Cat(Animal):
#        def speak(self):
#            return "Meow"
#
#    my_cat = Cat()
#    print(my_cat.speak())  # Output: Meow
#    ```
#
# 4. **Polymorphism**:
#    - The ability to present the same interface for different underlying data types. In Python, this can be achieved through method overriding in derived classes.
#
#    ```python
#    class Dog(Animal):
#        def speak(self):
#            return "Woof"
#
#    def animal_sound(animal):
#        print(animal.speak())
#
#    dog = Dog()
#    cat = Cat()
#    animal_sound(dog)  # Output: Woof
#    animal_sound(cat)  # Output: Meow
#    ```
#
# 5. **Abstraction**:
#    - The concept of hiding the complex implementation details and showing only the essential features of the object. This can be accomplished using abstract classes or interfaces in some object-oriented languages. In Python, the `abc` module provides the tools to define abstract base classes.
#
#    ```python
#    from abc import ABC, abstractmethod
#
#    class Shape(ABC):
#        @abstractmethod
#        def area(self):
#            pass
#
#    class Rectangle(Shape):
#        def __init__(self, width, height):
#            self.width = width
#            self.height = height
#
#        def area(self):
#            return self.width * self.height
#
#    my_rectangle = Rectangle(4, 5)
#    print(my_rectangle.area())  # Output: 20
#    ```
#
# ### Summary
#
# Object-Oriented Programming in Python allows developers to create classes that model real-world entities, encapsulating data and functionality. Through inheritance, polymorphism, encapsulation, and abstraction, developers can build flexible and maintainable applications. Python’s simplicity makes it an excellent language for practicing OOP concepts while developing software.
